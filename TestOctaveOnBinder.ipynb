% %% [markdown]
% # BinderでのOctaveのテスト

% %%
t=linspace(0,2*pi,101);
plot(t,sin(t));
xlabel("Japanese日");
ylabel("English");
% Out:
% ...
%     __axis_label__ at line 36 column 6
%     xlabel at line 59 column 8
%
% ...
%     __axis_label__ at line 36 column 6
%     xlabel at line 59 column 8
